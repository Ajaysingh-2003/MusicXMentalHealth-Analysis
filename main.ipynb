# %% [markdown]
# ## Effects of Music on Mental Health Analysis

# %% [markdown]
# ### Music Therapy

# %% [markdown]
# ##### Music Therapy is the process to positively effect the mental health of an indiviual using music. It can result in decrease of anxiety, sadness, depression and many other mental health problems.

# %% [markdown]
# ##### There are many factors and cases that show diffrent effect of music therapy on different indiviuals. Hence, here we are to study the interdependece or correlation between the various factors and the mental problems of a person.

# %% [markdown]
# #### Interpreting data
# ##### Block 0: Background
# ##### Respondents answer generic questions focused on musical background and listening habits.
#
# ##### Block 1: Music genres
# ##### Respondents rank how often they listen to 16 music genres, where they can select:
# <ul>
# <li>Never</li>
# <li>Rarely</li>
# <li>Sometimes</li>
# <li>Very frequently</li>
# </ul>
#
# ##### Block 2: Mental health
# ##### Respondents rank Anxiety, Depression, Insomnia, and OCD on a scale of 0 to 10, where:
#
# ##### 0 - I do not experience this.
# ##### 10 - I experience this regularly, constantly/or to an extreme.

# %% [markdown]
# ### Exploratoty Data Analysis

# %% [markdown]
# #### Import the libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Read the Dataset

# %%
df=pd.read_csv('mxmh_survey_results.csv')

# %%
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
df.tail()
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732     11-01-2022 22:26  18.0                   Spotify            1.0
# 733     11-03-2022 23:24  19.0   Other streaming service            6.0
# 734     11-04-2022 17:31  19.0                   Spotify            5.0
# 735     11-09-2022 01:55  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 731           Yes             Yes       No       Rock         Yes
# 732           Yes             Yes       No        Pop         Yes
# 733           Yes              No      Yes        Rap         Yes
# 734           Yes             Yes       No  Classical          No
# 735           Yes              No       No    Hip hop         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %% [markdown]
# #### Extracting more information about the Dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %% [markdown]
# #### Clean the Dataset by checking the presence of any null values.

# %%
df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# ...

# %% [markdown]
# #### Remove the null values in the Dataset

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Primary streaming service       0
# Hours per day                   0
# While working                   0
# Instrumentalist                 0
# Composer                        0
# Fav genre                       0
# Exploratory                     0
# Foreign languages               0
# BPM                             0
# Frequency [Classical]           0
# Frequency [Country]             0
# Frequency [EDM]                 0
# Frequency [Folk]                0
# Frequency [Gospel]              0
# Frequency [Hip hop]             0
# Frequency [Jazz]                0
# Frequency [K pop]               0
# Frequency [Latin]               0
# Frequency [Lofi]                0
# Frequency [Metal]               0
# Frequency [Pop]                 0
# Frequency [R&B]                 0
# Frequency [Rap]                 0
# Frequency [Rock]                0
# Frequency [Video game music]    0
# ...

# %% [markdown]
# ## Visualise the Relationships of the features

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(5,3),dpi=200)
sns.histplot(x=df['Age'],bins=30,color='darkblue',kde=True)
plt.xlabel("Age of the listeners")
plt.xticks(rotation=90)
plt.title("Count of the Age of Music Listeners")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### The above graph shows us that most of the music listeners are early teenagers and people in their early twenties.

# %% [markdown]
# #### Simplify the values in the Primary streaming services features.

# %%
df['Primary streaming service']=df['Primary streaming service'].replace({'I do not use a streaming service.':'None','Other streaming service':'Others'})

# %% [markdown]
# #### Music Platform Analysis

# %%
fig,ax=plt.subplots()
label=['Spotify','YouTube Music','None','Apple Music','Others','Pandora']
platform_data=df['Primary streaming service'].value_counts()
ax.pie(platform_data,autopct='%1.1f%%',labels=label,labeldistance=1.1)
plt.title("Percentage of people on Different Streaming Platforms")
plt.show()

# %% [markdown]
# ##### The above Pie Chart shows us that most of the users are streaming music on Spotify and the least number of users are on Pandora.

# %% [markdown]
# ### Lets visualise the amount of time that people spend on different music streaming platforms.

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(5,3),dpi=200)
sns.scatterplot(x='Age',data=df,y='Hours per day',hue='Primary streaming service',)
plt.legend(loc=(0.9,0.1))
plt.title("Amount of time people spend on Different Platfroms")
plt.show()

# %% [markdown]
# #### The spotify users of the agegroup between 10-30 years spend the most time listening to music.
# #### There is also a unrealistic outlier which tells that 3 people listen to music for 24hrs a day.

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(5,3),dpi=150)
sns.boxplot(x='Primary streaming service',y='Hours per day',data=df)
plt.ylabel("Age group of Listeners")
plt.xticks(rotation=35)
plt.title("Number of Hours spent on different streaming Platforms")
plt.show()

# %% [markdown]
# ### The favoruite music genre depending on age.

# %%
sns.set_style('whitegrid')
fig,ax=plt.subplots()
sns.boxplot(x='Fav genre',y='Age',data=df)
plt.title("Favorite Genre depending on the Age")
plt.xticks(rotation=90)
ax.tick_params(axis='both',labelsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Drop the Timestamp and Permissions column.

# %%
df=df.drop(['Timestamp','Permissions'],axis=1)

# %% [markdown]
# #### Effect of Music Genre on Blood Pressure Measurement.

# %%
fig=plt.figure(dpi=150)
sns.set_style('ticks')
sns.scatterplot(x='Fav genre',y='BPM',data=df,marker='x')
plt.ylim(0,250)
plt.xticks(rotation=55)
plt.tick_params(axis='x',labelsize=7)
plt.tight_layout()
plt.title("Affect of Favorite Music genre on BPM",color='darkblue')
plt.show()

# %% [markdown]
# ##### From the analysis above we can conclude that loud or heavy music genres like 'Rock', 'Pop' and 'Metal' music has population with an higher average of Blood Pressure.

# %% [markdown]
# #### Replace the 'Yes' and 'No' values in the DataFrame with binary values such and '1' and '0' respectively.

# %%
df.replace(['Yes','No'],[1,0],inplace=True)
df.head()
# Out:
#     Age Primary streaming service  Hours per day  While working  \
# 2  18.0                   Spotify            4.0              0
# 3  61.0             YouTube Music            2.5              1
# 4  18.0                   Spotify            4.0              1
# 5  18.0                   Spotify            5.0              1
# 6  18.0             YouTube Music            3.0              1
#
#    Instrumentalist  Composer         Fav genre  Exploratory  \
# 2                0         0  Video game music            0
# 3                0         1              Jazz            1
# 4                0         0               R&B            1
# 5                1         1              Jazz            1
# 6                1         0  Video game music            1
#
#    Foreign languages    BPM  ...  Frequency [Pop]  Frequency [R&B]  \
# 2                  1  132.0  ...           Rarely            Never
# 3                  1   84.0  ...        Sometimes        Sometimes
# ...

# %% [markdown]
# #### Let's find the correlation between the features of the DataSet.

# %%
heat_corr=df[['Age','Hours per day','While working','Instrumentalist','Composer','Exploratory','Foreign languages']]
heat_map_corr=heat_corr.corr()
sns.heatmap(heat_map_corr,annot=True,fmt='.3f',linewidths=2,cmap='crest')
plt.show()

# %% [markdown]
# #### <b>Strong linear trends</b>
#
# ##### As expected, there is a a significant correlation between individuals that play music and individuals that compose music. Similarly, there is also a strong relationship between the total hours listening per day and hours listening while working.
#
# #### <b>Weaker linear trends: exploratory respondents</b>
# <ul>
# <li>The more hours spent listening to music, the more likely an individual actively explores new music.</li>
# <li>Individuals that listen to music while working are more likely to explore new music and listen to music in different languages.</li>
# <li>Individuals that listen to music in foreign languages are more likely to explore new music.</li>
# <li>Older individuals are less inclined to explore new music.</li>
# </ul>

# %% [markdown]
# ## Mental Health analysis

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(10,4))
labels=['Anxiety','Depression','Insomnia','OCD']
for label in labels:
    ax=plt.subplot(1,4,labels.index(label)+1)
    ax.set_title(label)
    sns.kdeplot(df[label],fill=True,color='darkgreen')
    plt.tight_layout()
plt.show()

# %% [markdown]
# ##### The kernel distribution plot generated above shows that mental health issues like "Anxiety" and "Depression" are induced at higher rankings i.e they are experienced at higher levels by the music listeners.
#
# ##### Whereas issues like "Insomnia" and "OCD" are not present in higher levels as they have a very low rank of occurence in the music listeners.

# %% [markdown]
# #### Drop the other columns that are uneccesary for exploratory data analysis.

# %%
df.columns
# Out:
# Index(['Age', 'Primary streaming service', 'Hours per day', 'While working',
#        'Instrumentalist', 'Composer', 'Fav genre', 'Exploratory',
#        'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects'],
#       dtype='object')

# %%
df=df.drop(['Frequency [Classical]',
       'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
       'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
       'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
       'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
       'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]'],axis=1)

# %%
df.head()
# Out:
#     Age Primary streaming service  Hours per day  While working  \
# 2  18.0                   Spotify            4.0              0
# 3  61.0             YouTube Music            2.5              1
# 4  18.0                   Spotify            4.0              1
# 5  18.0                   Spotify            5.0              1
# 6  18.0             YouTube Music            3.0              1
#
#    Instrumentalist  Composer         Fav genre  Exploratory  \
# 2                0         0  Video game music            0
# 3                0         1              Jazz            1
# 4                0         0               R&B            1
# 5                1         1              Jazz            1
# 6                1         0  Video game music            1
#
#    Foreign languages    BPM  Anxiety  Depression  Insomnia  OCD Music effects
# 2                  1  132.0      7.0         7.0      10.0  2.0     No effect
# ...

# %% [markdown]
# ### Analysis of Mental health Problems

# %%
f, axes = plt.subplots(2, 2, figsize=(10, 7))
sns.countplot(ax=axes[0, 0], data=df, x="Anxiety")
sns.countplot(ax=axes[0, 1], data=df, x="Depression")
sns.countplot(ax=axes[1, 0], data=df, x="Insomnia")
sns.countplot(ax=axes[1, 1], data=df, x="OCD")
plt.suptitle("Count of Rankings in different mental health problems")
plt.show()

# %% [markdown]
# #### As we can observe from the analysis given above. Issues like "Depression and "Anxiety" are more prevalent and serious as compared to the other mental health issues.

# %%
sns.set_style("whitegrid")
graph = sns.FacetGrid(df, col="Music effects")
graph.map(sns.scatterplot, "Age", "Hours per day", color='red')
plt.suptitle("Effect of music on mental health according to age")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### From the Scatterplot given above, we can conclude that most of the music listeners have seen positive changes in their mental health.
# #### Whereas a small but negligible precentage claims that listening to music has worsen their mental health.
# #### Most people who have benifited from listening to music belong to the group of teenagers and people in their early twenties.

# %% [markdown]
# ### Extract the clean Dataset

# %%
clean_csv_data=df.to_csv("Cleanmxmh_survey.csv",index=True)
print("File Created Succesfully")
# Out:
# File Created Succesfully

# %% [markdown]
# ## Building the model

# %%
#import the machine learning libraries from scikit learn
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import make_column_transformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier , DecisionTreeRegressor, export_graphviz
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier , AdaBoostClassifier ,RandomForestRegressor , AdaBoostRegressor
from xgboost import XGBClassifier , XGBRegressor
from sklearn.linear_model import LinearRegression ,LogisticRegression, Ridge, RidgeCV, RidgeClassifier, RidgeClassifierCV, Lasso
from sklearn.neighbors import KNeighborsRegressor , KNeighborsClassifier
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score , classification_report , accuracy_score , f1_score , precision_score
import pickle

# %% [markdown]
# ### Splitting the Data

# %%
X=df.drop('Music effects',axis=1)
y=df[['Music effects']]

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X.head()
# Out:
#     Age Primary streaming service  Hours per day  While working  \
# 2  18.0                   Spotify            4.0              0
# 3  61.0             YouTube Music            2.5              1
# 4  18.0                   Spotify            4.0              1
# 5  18.0                   Spotify            5.0              1
# 6  18.0             YouTube Music            3.0              1
#
#    Instrumentalist  Composer         Fav genre  Exploratory  \
# 2                0         0  Video game music            0
# 3                0         1              Jazz            1
# 4                0         0               R&B            1
# 5                1         1              Jazz            1
# 6                1         0  Video game music            1
#
#    Foreign languages    BPM  Anxiety  Depression  Insomnia  OCD
# 2                  1  132.0      7.0         7.0      10.0  2.0
# 3                  1   84.0      9.0         7.0       3.0  3.0
# ...

# %%
y.head()
# Out:
#   Music effects
# 2     No effect
# 3       Improve
# 4       Improve
# 5       Improve
# 6       Improve

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (369, 14)
# (369, 1)

# %% [markdown]
# ### Split the Categorical and numerical data

# %%
object_cols = df.select_dtypes(include="object").columns.tolist()
num_cols = df.select_dtypes(include="number").columns.tolist()

# %%
print("Numeric Columns:",num_cols)
print("Categorical Columns:",object_cols)
# Out:
# Numeric Columns: ['Age', 'Hours per day', 'While working', 'Instrumentalist', 'Composer', 'Exploratory', 'Foreign languages', 'BPM', 'Anxiety', 'Depression', 'Insomnia', 'OCD']
# Categorical Columns: ['Primary streaming service', 'Fav genre', 'Music effects']

# %% [markdown]
# ### Feature Scaling

# %%
Standard_Scaler=StandardScaler()
X_train[num_cols] = Standard_Scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = Standard_Scaler.transform(X_test[num_cols])

# %% [markdown]
# ### Encoding the values

# %%
label_encoder = LabelEncoder() #To convert Categorical Data to Numeric Data
y_train = label_encoder.fit_transform(y_train)
object_columns = X_train.select_dtypes(include=['object']).columns
for column in object_columns:
    X_train[column] = label_encoder.fit_transform(X_train[column])
    
y_test = label_encoder.fit_transform(y_test)
object_columns = X_test.select_dtypes(include=['object']).columns
for column in object_columns:
    X_test[column] = label_encoder.fit_transform(X_test[column])

# %%
X_train.head()
# Out:
#           Age  Primary streaming service  Hours per day  While working  \
# 68   1.468342                          0      -0.235109       0.500847
# 644 -0.735605                          2       0.097669       0.500847
# 278 -0.911920                          4       0.097669       0.500847
# 686 -0.559289                          1      -0.900664       0.500847
# 603  1.909131                          1      -0.900664      -1.996619
#
#      Instrumentalist  Composer  Fav genre  Exploratory  Foreign languages  \
# 68          1.458464  1.996619         10     0.605530           0.851058
# 644        -0.685653 -0.500847          2     0.605530           0.851058
# 278         1.458464  1.996619         15     0.605530           0.851058
# 686        -0.685653 -0.500847          0    -1.651446          -1.175009
# 603        -0.685653 -0.500847         14    -1.651446          -1.175009
#
#           BPM   Anxiety  Depression  Insomnia       OCD
# ...

# %% [markdown]
# ### Model Building using Scikit-Learn

# %%
#Linear Regression Model
regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_lrpred=regressor.predict(X_test)
acc=r2_score(y_test,y_lrpred)
coefficeient=regressor.coef_
print("The accuracy of the linear regression model is:",np.round(acc*100,2))
print("The coefficients are:",coefficeient)
# Out:
# The accuracy of the linear regression model is: 3.52
# The coefficients are: [-0.00787927 -0.00212341  0.02354977 -0.05675173  0.01382613 -0.05392248
#   0.01204701 -0.06845025  0.02484494  0.02868841 -0.11055786  0.05788226
#   0.02165776  0.01559047]

# %% [markdown]
# #### We can observe that we are handling a categorical oriented datadet where we have to predict the outcome based on the categories of effect on mental health. So, in such cases Regression models will provide very less accuracy and won't provide satisfactory results.
#
# #### Hence, we will be using Classifier models from now onwards.

# %% [markdown]
# ### Ridge Classification

# %%
#Ridge Classification Model
alphas=[0.01,0.1,1,10,1000]
for alpha in alphas:
    ridgecl=RidgeClassifier(alpha=alpha,max_iter=100,solver='auto')
    ridgecl.fit(X_train,y_train)
    y_ridgepred=ridgecl.predict(X_test)
    ridgeacc=accuracy_score(y_test,y_ridgepred)
print("The accuracy of Ridge Classification is:",np.round(ridgeacc*100,2))
print(classification_report(y_test,y_ridgepred))
# Out:
# The accuracy of Ridge Classification is: 73.68
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85       182
#            1       0.00      0.00      0.00        60
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.74       247
#    macro avg       0.25      0.33      0.28       247
# weighted avg       0.54      0.74      0.63       247

# %% [markdown]
# #### Ridge Classification provided us a great accuracy of 73.6%. But we can try various other models that may provide greater accuracy scores.

# %% [markdown]
# ### Logistic Regression
#
# #### Logistic Regression is a type of classification model which is used for binary classification of the outcome.

# %%
logis=LogisticRegression()
logis.fit(X_train,y_train)
y_logis_pred=logis.predict(X_test)
logis_acc=accuracy_score(y_test,y_logis_pred)
print("The accuracy for logistic regression is:",np.round(logis_acc*100,2))
print(classification_report(y_test,y_logis_pred))
# Out:
# The accuracy for logistic regression is: 72.06
#               precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84       182
#            1       0.31      0.07      0.11        60
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.72       247
#    macro avg       0.35      0.34      0.32       247
# weighted avg       0.62      0.72      0.64       247

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc = DecisionTreeClassifier(max_depth = 10, random_state=1)
dtc.fit(X_train, y_train)
y_dtc_pred = dtc.predict(X_test)
dtc_acc=accuracy_score(y_test,y_dtc_pred)
print("The accuracy of Decision tree Classifier is:",np.round(dtc_acc*100,2))
print(classification_report(y_test,y_dtc_pred))
# Out:
# The accuracy of Decision tree Classifier is: 69.23
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82       182
#            1       0.35      0.20      0.26        60
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.69       247
#    macro avg       0.37      0.36      0.36       247
# weighted avg       0.65      0.69      0.66       247

# %% [markdown]
# ### Visualising the Decision Tree Algorithm

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dtc,
                   filled=True)

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc=RandomForestClassifier(n_estimators=100,random_state=30)
rfc.fit(X_train,y_train)
y_rfc_pred=rfc.predict(X_test)
rfc_acc=accuracy_score(y_test,y_rfc_pred)
print("The accuracy of Random Forest Classifier is:",np.round(rfc_acc*100,2))
# Out:
# The accuracy of Random Forest Classifier is: 72.47

# %% [markdown]
# ### KNeighbour Classifier

# %%
kneigh=KNeighborsClassifier(n_neighbors=1)
kneigh.fit(X_train,y_train)
y_kn_pred=kneigh.predict(X_test)
kn_acc=accuracy_score(y_test,y_kn_pred)
print("The accuracy score of Kneighbours classifier is:",np.round(kn_acc*100,2))
# Out:
# The accuracy score of Kneighbours classifier is: 63.97

# %% [markdown]
# ### Analysing the accuracy of the models

# %%
models={"Ridge Classification":ridgeacc*100,
        "LogisticRegression":logis_acc*100,
        "Decision Tree Classification":dtc_acc*100,
        "RandomForestClassifier":rfc_acc*100,
        "Kneighbours Classification":kn_acc*100}
models = {k:[v] for k,v in models.items()}
df_accuracy=pd.DataFrame(models)

# %%
df_accuracy
# Out:
#    Ridge Classification  LogisticRegression  Decision Tree Classification  \
# 0             73.684211           72.064777                     69.230769
#
#    RandomForestClassifier  Kneighbours Classification
# 0               72.469636                   63.967611

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(7,4))
sns.barplot(df_accuracy)
plt.tight_layout()
plt.xlabel("ML Models")
plt.ylabel("Accuracy of Models")
plt.title("Accuracy of various ML Models")
plt.xticks(rotation=35)
plt.show()

# %% [markdown]
# ### From the above barplot, we can conclude that the Ridge Classification model provides us the best accuracy on the dataset.

# %% [markdown]
# ## <b> Saving the Model</b>

# %%
with open('FinalModel.pkl','wb') as file:
    pickle.dump(ridgecl,file)

# %% [markdown]
# ## Final Analysis of the project

# %% [markdown]
# ### After completing this project and analysing the dataset completely, we have inferred the following
#
# #### Most of the music listening audience falls under the category of teenagers and people in their early twenties.
#
# #### In the terms of streaming platform, Spotify is widely used by maximum number of the population.
#
# #### Most time consuming music streaming platform is Spotify with the most numbers of hours of played music. On the other hand, the people who spend the most time listening to music are teenagers and kids below 10 years of age.
#
# #### Talking about the popularity of the music genres, loud and heavy music genres such as "Rock", "Pop" and "Metal" are the most popular categories with the most number of hours played by youngsters. Whereas genres like "Gospel" and "Classical" are popular among the people and their late thirties and people who belong to the older generation.
#
# #### It seems that the people who listen to the heavy genres like Rock and Pop tend to have a higher blood pressure measure than the people who listen to other genre of music.

# %% [markdown]
# ### Trends among the features in the Dataset
#
# #### <b>Strong linear trends</b>
#
# ##### As expected, there is a a significant correlation between individuals that play music and individuals that compose music. Similarly, there is also a strong relationship between the total hours listening per day and hours listening while working.
#
# #### <b>Weaker linear trends: exploratory respondents</b>
# <ul>
# <li>The more hours spent listening to music, the more likely an individual actively explores new music.</li>
# <li>Individuals that listen to music while working are more likely to explore new music and listen to music in different languages.</li>
# <li>Individuals that listen to music in foreign languages are more likely to explore new music.</li>
# <li>Older individuals are less inclined to explore new music.</li>
# </ul>

# %% [markdown]
# #### The population that listen to music are mostly suffering from mental problems like Depression and Anxiety at higher and critical levels. This also shows that they are the ones who listen to music for higher period of time.
#
# #### whereas problems like Insomnia and OCD are present in negligible and normal amounts and are not present at an alarming rate in the people who listen to music.

# %% [markdown]
# ### <b>Final Effect music on mental health problems</b>
#
# #### It is seen that music has an overall positive effect on the mental health of people that helps in reducing stress and depression problems.
#
# #### There are a fine amount of people who claim that they feel or see no effect of listening to music on their mental health.
#
# #### Whereas, there is a negligible percentage of population which is very small in number and they claim that listening to music has negatively impacted or worsened their mental health.
